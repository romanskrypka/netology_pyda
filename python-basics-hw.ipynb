# %% [markdown]
# **Задание 1**. Даны 2 строки: *long_phrase* и *short_phrase*.
# Напишите код, который проверяет действительно ли длинная фраза *long_phrase* длиннее короткой *short_phrase*. И выводит *True* или *False* в зависимости от результата сравнения.

# %%
long_phrase = 'Насколько проще было бы писать программы, если бы не заказчики'
short_phrase = '640Кб должно хватить для любых задач. Билл Гейтс (по легенде)'

# %%
print('long_phrase' > 'short_phrase')
len('long_phrase') > len('short_phrase')
# Out:
# False
# False

# %% [markdown]
# **Задание 2**. Дано значение объема файла в байтах. Напишите перевод этого значения в мегабайты в формате: "*Объем файла равен 213.68Mb*"

# %%
Мегабайт = 1048576 #байт
Байт = int(input("Обём файла в байтах: "))
Объём_файла = round(Байт / Мегабайт, 2)
print("Обём файла равен", Объём_файла,"Mb")
# Out:
# Обём файла в байтах: 224059719
# Обём файла равен 213.68 Mb

# %% [markdown]
# **Задание 3**. Разработать приложение для определения знака зодиака по дате рождения. Пример:
#
# Введите месяц: март
#
# Введите число: 6
#
# Вывод:
# Рыбы

# %%
месяц = str(input("Введите месяц: "))
дата = int(input("Введите число: "))
if месяц == "декабрь" and 21 < дата <=31 or\
   месяц == "январь" and 1 <= дата <=20:
    print(str("Козерог"))
elif месяц == "январь" and 20 < дата <=31 or\
     месяц == "февраль" and 1 <= дата <=19:
    print(str("Водолей"))
elif месяц == "февраль" and 19 < дата <=29 or\
     месяц == "март" and 1 <= дата <=20:
    print(str("Рыбы"))
elif месяц == "март" and 20 < дата <=31 or\
     месяц == "апрель" and 1 <= дата <=20:
    print(str("Овен"))
elif месяц == "апрель" and 20 < дата <=30 or\
     месяц == "май" and 1 <= дата <=21:
    print(str("Телец"))
elif месяц == "май" and 21 < дата <=31 or\
     месяц == "июнь" and 1 <= дата <=21:
    print(str("Близнецы"))
elif месяц == "июнь" and 21 < дата <=30 or\
     месяц == "июль" and 1 <= дата <=23:
    print(str("Рак"))
elif месяц == "июль" and 23 < дата <=31 or\
     месяц == "август" and 1 <= дата <=23:
    print(str("Лев"))
elif месяц == "август" and 23 < дата <=31 or\
     месяц == "сентябрь" and 1 <= дата <=23:
    print(str("Дева"))
elif месяц == "сентябрь" and 23 < дата <=30 or\
     месяц == "октябрь" and 1 <= дата <=23:
    print(str("Весы"))
elif месяц == "октябрь" and 23 < дата <=31 or\
     месяц == "ноябрь" and 1 <= дата <=22:
    print(str("Скорпион"))
elif месяц == "ноябрь" and 22 < дата <=30 or\
     месяц == "декабрь" and 1 <= дата <=21:
    print(str("Стрелец"))
else:
    print("Ошибка - вы ввели месяц с Большой буквы и/или допустили ошибку в слове и/или ввели некорректную дату")
# Out:
# Введите месяц: Ноябрь
# Введите число: 56
# Ошибка - вы ввели месяц с Большой буквы и/или допустили ошибку в слове и/или ввели некорректную дату

# %% [markdown]
# **Задание 4**. Нужно разработать приложение для финансового планирования.
# Приложение учитывает сколько уходит на ипотеку, "на жизнь" и сколько нужно отложить на пенсию.
# Пользователь вводит:
# - заработанную плату в месяц.
# - сколько процентов от ЗП уходит на ипотеку.
# - сколько процентов от ЗП уходит "на жизнь".
# - сколько раз приходит премия в год.
#
# Остальная часть заработанной платы откладывается на пенсию.
#
# Также пользователю приходит премия в размере зарплаты, от которой половина уходит на отпуск, а вторая половина откладывается.
#
# Программа должна учитывать сколько премий было в год.
#
# Нужно вывести сколько денег тратит пользователь на ипотеку и сколько он накопит за год.
#
# Пример:
#
# Введите заработанную плату в месяц: 100000
#
# Введите сколько процентов уходит на ипотеку: 30
#
# Введите сколько процентов уходит на жизнь: 50
#
# Введите количество премий за год: 2
#
# Вывод:
# На ипотеку было потрачено: 360000 рублей
# Было накоплено: 340000 рублей

# %%
ЗП_в_месяц = int(input('Заработная плата в месяц: '))
Ипотека = float(input('% от ЗП на Ипотеку: '))
Жизнь = float(input('% от ЗП на Жизнь: '))
Премия_Кол = int(input('Количество премий в год: '))
Пенсия = ЗП_в_месяц - (ЗП_в_месяц * Ипотека / 100) - (ЗП_в_месяц * Жизнь / 100)
Премия = ЗП_в_месяц
Отпуск = Премия / 2
Накопления = Премия / 2
Период = 12
Ипотека_период = (ЗП_в_месяц * Ипотека / 100) * Период
Накопления_период = Накопления * Премия_Кол
print("Вывод: На ипотеку было потрачено:", int(Ипотека_период), "рублей. Было накоплено:", int(Накопления_период), "рублей")
# Out:
# Заработная плата в месяц: 100000
# % от ЗП на Ипотеку: 30
# % от ЗП на Жизнь: 50
# Количество премий в год: 2
# Вывод: На ипотеку было потрачено: 360000 рублей. Было накоплено: 100000 рублей
